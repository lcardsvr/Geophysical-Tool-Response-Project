# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime
from scipy import stats


import requests
import json

# %%
from matplotlib import style
style.use('fivethirtyeight')

import datetime as dt

# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
from sqlalchemy.ext.declarative import declarative_base

import sqlite3

# %% [markdown]
# Loading Data

# %%
# create engine to Dataset 1 .sqlite
engine_01 = create_engine("sqlite:///Resources/FMG_2023_Field.db")

# %%
# Create the inspector and connect it to the engine
inspector_01 = inspect(engine_01)
# Collect the names of tables within the database
inspector_01.get_table_names()
# Out:
# ['Century_0028AA',
#  'Century_0028AA_cals',
#  'Century_0028AA_header',
#  'Century_9013A',
#  'Century_9013A_cals',
#  'Century_9013A_header',
#  'Century_9238AA',
#  'Century_9238AA_cals',
#  'Century_9238AA_header',
#  'Century_9238CA',
#  'Century_9238CA_cals',
#  'Century_9238CA_header',
#  'Century_9622A',
#  'Century_9622A_cals',
#  'Century_9622A_header',
#  'Century_9622C',
#  'Century_9622C_cals',
#  'Century_9622C_header',
#  'sqlite_sequence']

# %%
# View all of the classes that automap found

# Using the inspector to print the column names within the 'measurement' table and its types

print ("---- 0028AA table information --------")

columns = inspector_01.get_columns('Century_0028AA')
for column in columns:
    print(column["name"], column["type"])

print ("---- 0028AA_cals table information --------")

columns = inspector_01.get_columns('Century_0028AA_cals')
for column in columns:
    print(column["name"], column["type"])


print ("---- 0028AA_header table information --------")

columns = inspector_01.get_columns('Century_0028AA_header')
for column in columns:
    print(column["name"], column["type"])
# Out:
# ---- 0028AA table information --------
# Depth_M FLOAT
# CALIPER_MM FLOAT
# DENSITY_G/CC FLOAT
# POR(DEN)_PERCENT FLOAT
# DENSITY_CPS FLOAT
# TENSION_CPS FLOAT
# TIME_MINUTES FLOAT
# well TEXT
# file TEXT
# TIME_SECONDS FLOAT
# CALIPER_CPS FLOAT
# TENSION_POUNDS FLOAT
# ind INTEGER
# ---- 0028AA_cals table information --------
# dateTime DATETIME
# sensor TEXT
# unitsStandard TEXT
# standard FLOAT
# response FLOAT
# file TEXT
# well TEXT
# toolSerial TEXT
# ind INTEGER
# ---- 0028AA_header table information --------
# filetype TEXT
# filetypeID TEXT
# sysversion TEXT
# sysserial TEXT
# unit TEXT
# truckcal TEXT
# interval FLOAT
# start_depth TEXT
# end_depth TEXT
# dir TEXT
# engUnits TEXT
# toolSerial TEXT
# runDate DATETIME
# runTime TEXT
# Company TEXT
# Well TEXT
# Field TEXT
# County TEXT
# State TEXT
# Section TEXT
# Township TEXT
# Range TEXT
# Latitude TEXT
# Longitude TEXT
# LogMeasFrom TEXT
# DrillMeasFrom TEXT
# PermDatum TEXT
# ElevPermDatum TEXT
# ElevKellyBushing TEXT
# ElevDrillFloor TEXT
# ElevGndLevel TEXT
# DepthDriller TEXT
# CasingDiameter TEXT
# CasingBottom TEXT
# CasingType TEXT
# CasingThickness TEXT
# TimeCircStop TEXT
# LoggingUnit TEXT
# FieldOffice TEXT
# RecordedBy TEXT
# OtherServ_1 TEXT
# OtherServ_2 TEXT
# Remarks_1 TEXT
# Remarks_2 TEXT
# BitSize TEXT
# MeanSurfTemp TEXT
# TempGradient TEXT
# MagnDecl TEXT
# DensityMatrix TEXT
# NeutronMatrix TEXT
# MatrixDelta TEXT
# FluidDelta TEXT
# MudSampdrc TEXT
# MudResistivity TEXT
# MudTemp TEXT
# ResMudFiltrate TEXT
# TempMudFiltrate TEXT
# ResMudCake TEXT
# TempMudCake TEXT
# BoreholeFluid TEXT
# FluidDensity TEXT
# FluidVisc TEXT
# FluidpHy TEXT
# ElectricLogCut TEXT
# RigNum TEXT
# UWI TEXT
# License TEXT
# CasingOD TEXT
# Location TEXT
# RunNo TEXT
# ApiNo TEXT
# Witnessed TEXT
# ToolModuleVersion BIGINT
# Arrival TEXT
# Depart TEXT
# loggerTD TEXT
# Caliper TEXT
# runDateTime DATETIME
# file TEXT
# filepath TEXT
# ind INTEGER

# %%
# View all of the classes that automap found

# Using the inspector to print the column names within the 'measurement' table and its types

print ("---- Century_9013A table information --------")

columns = inspector_01.get_columns('Century_9013A')
for column in columns:
    print(column["name"], column["type"])

print ("---- Century_9013A_cals table information --------")

columns = inspector_01.get_columns('Century_9013A_cals')
for column in columns:
    print(column["name"], column["type"])


print ("---- Century_9013A_header table information --------")

columns = inspector_01.get_columns('Century_9013A_header')
for column in columns:
    print(column["name"], column["type"])
# Out:
# ---- Century_9013A table information --------
# Depth_M FLOAT
# GAM(NAT)_API-GR FLOAT
# RES(FL)_OHM-M FLOAT
# TEMP_DEG C FLOAT
# DEL TEMP_DEG C FLOAT
# TENSION_CPS FLOAT
# TIME_MINUTES FLOAT
# well TEXT
# file TEXT
# TEMP_DEG REAL
# DEL REAL
# TIME_SECONDS FLOAT
# ind INTEGER
# ---- Century_9013A_cals table information --------
# dateTime DATETIME
# sensor TEXT
# unitsStandard TEXT
# standard FLOAT
# response FLOAT
# file TEXT
# well TEXT
# toolSerial TEXT
# ind INTEGER
# ---- Century_9013A_header table information --------
# filetype TEXT
# filetypeID TEXT
# sysversion TEXT
# sysserial TEXT
# unit TEXT
# truckcal TEXT
# interval FLOAT
# start_depth TEXT
# end_depth TEXT
# dir TEXT
# engUnits TEXT
# toolSerial TEXT
# runDate DATETIME
# runTime TEXT
# Company TEXT
# Well TEXT
# Field TEXT
# County TEXT
# State TEXT
# Section TEXT
# Township TEXT
# Range TEXT
# Latitude TEXT
# Longitude TEXT
# LogMeasFrom TEXT
# DrillMeasFrom TEXT
# PermDatum TEXT
# ElevPermDatum TEXT
# ElevKellyBushing TEXT
# ElevDrillFloor TEXT
# ElevGndLevel TEXT
# DepthDriller TEXT
# CasingDiameter TEXT
# CasingBottom TEXT
# CasingType TEXT
# CasingThickness TEXT
# TimeCircStop TEXT
# LoggingUnit TEXT
# FieldOffice TEXT
# RecordedBy TEXT
# OtherServ_1 TEXT
# OtherServ_2 TEXT
# Remarks_1 TEXT
# Remarks_2 TEXT
# BitSize TEXT
# MeanSurfTemp TEXT
# TempGradient TEXT
# MagnDecl TEXT
# DensityMatrix TEXT
# NeutronMatrix TEXT
# MatrixDelta TEXT
# FluidDelta TEXT
# MudSampdrc TEXT
# MudResistivity TEXT
# MudTemp TEXT
# ResMudFiltrate TEXT
# TempMudFiltrate TEXT
# ResMudCake TEXT
# TempMudCake TEXT
# BoreholeFluid TEXT
# FluidDensity TEXT
# FluidVisc TEXT
# FluidpHy TEXT
# ElectricLogCut TEXT
# RigNum TEXT
# UWI TEXT
# License TEXT
# CasingOD TEXT
# Location TEXT
# RunNo TEXT
# ApiNo TEXT
# Witnessed TEXT
# ToolModuleVersion BIGINT
# Arrival TEXT
# Depart TEXT
# loggerTD TEXT
# Caliper TEXT
# runDateTime DATETIME
# file TEXT
# filepath TEXT
# ind INTEGER

# %%
# View all of the classes that automap found

# Using the inspector to print the column names within the 'measurement' table and its types

print ("---- Century_9057A table information --------")

columns = inspector_01.get_columns('Century_9057A')
for column in columns:
    print(column["name"], column["type"])

print ("---- Century_9057A_cals table information --------")

columns = inspector_01.get_columns('Century_9057A_cals')
for column in columns:
    print(column["name"], column["type"])


print ("---- Century_9057A_header table information --------")

columns = inspector_01.get_columns('Century_9057A_header')
for column in columns:
    print(column["name"], column["type"])
# Out:
# ---- Century_9057A table information --------
# ---- Century_9057A_cals table information --------
# ---- Century_9057A_header table information --------

# %%
# View all of the classes that automap found

# Using the inspector to print the column names within the 'measurement' table and its types

print ("---- Century_9238AA table information --------")

columns = inspector_01.get_columns('Century_9238AA')
for column in columns:
    print(column["name"], column["type"])

print ("---- Century_9238AA_cals table information --------")

columns = inspector_01.get_columns('Century_9238AA_cals')
for column in columns:
    print(column["name"], column["type"])


print ("---- Century_9238AA_header table information --------")

columns = inspector_01.get_columns('Century_9238AA_header')
for column in columns:
    print(column["name"], column["type"])
# Out:
# ---- Century_9238AA table information --------
# Depth_M FLOAT
# GAM(NAT)_API-GR FLOAT
# RES(SG)_OHM-M FLOAT
# CALIPER_MM FLOAT
# DENSITY_G/CC FLOAT
# CURRENT_UA FLOAT
# VOLTAGE_MV FLOAT
# POR(DEN)_PERCENT FLOAT
# DENSITY_CPS FLOAT
# TENSION_CPS FLOAT
# TIME_MINUTES FLOAT
# well TEXT
# file TEXT
# TIME_SECONDS FLOAT
# CALIPERL_MM FLOAT
# TENSION_POUNDS FLOAT
# ind INTEGER
# ---- Century_9238AA_cals table information --------
# dateTime DATETIME
# sensor TEXT
# unitsStandard TEXT
# standard FLOAT
# response FLOAT
# file TEXT
# well TEXT
# toolSerial TEXT
# ind INTEGER
# ---- Century_9238AA_header table information --------
# filetype TEXT
# filetypeID TEXT
# sysversion TEXT
# sysserial NUMERIC
# unit TEXT
# truckcal TEXT
# interval FLOAT
# start_depth TEXT
# end_depth TEXT
# dir TEXT
# engUnits TEXT
# toolSerial TEXT
# runDate DATETIME
# runTime TEXT
# Company TEXT
# Well TEXT
# Field TEXT
# County TEXT
# State TEXT
# Section TEXT
# Township TEXT
# Range TEXT
# Latitude TEXT
# Longitude TEXT
# LogMeasFrom TEXT
# DrillMeasFrom TEXT
# PermDatum TEXT
# ElevPermDatum TEXT
# ElevKellyBushing TEXT
# ElevDrillFloor TEXT
# ElevGndLevel TEXT
# DepthDriller TEXT
# CasingDiameter TEXT
# CasingBottom TEXT
# CasingType TEXT
# CasingThickness TEXT
# TimeCircStop TEXT
# LoggingUnit TEXT
# FieldOffice TEXT
# RecordedBy TEXT
# OtherServ_1 TEXT
# OtherServ_2 TEXT
# Remarks_1 TEXT
# Remarks_2 TEXT
# BitSize TEXT
# MeanSurfTemp TEXT
# TempGradient TEXT
# MagnDecl TEXT
# DensityMatrix TEXT
# NeutronMatrix TEXT
# MatrixDelta TEXT
# FluidDelta TEXT
# MudSampdrc TEXT
# MudResistivity TEXT
# MudTemp TEXT
# ResMudFiltrate TEXT
# TempMudFiltrate TEXT
# ResMudCake TEXT
# TempMudCake TEXT
# BoreholeFluid TEXT
# FluidDensity TEXT
# FluidVisc TEXT
# FluidpHy TEXT
# ElectricLogCut TEXT
# RigNum TEXT
# UWI TEXT
# License TEXT
# CasingOD TEXT
# Location TEXT
# RunNo TEXT
# ApiNo TEXT
# Witnessed TEXT
# ToolModuleVersion BIGINT
# Arrival TEXT
# Depart TEXT
# loggerTD TEXT
# Caliper TEXT
# runDateTime DATETIME
# file TEXT
# filepath TEXT
# ind INTEGER

# %%
# View all of the classes that automap found

# Using the inspector to print the column names within the 'measurement' table and its types

print ("---- Century_9622A table information --------")

columns = inspector_01.get_columns('Century_9622A')
for column in columns:
    print(column["name"], column["type"])

print ("---- Century_9622A_cals table information --------")

columns = inspector_01.get_columns('Century_9622A_cals')
for column in columns:
    print(column["name"], column["type"])


print ("---- Century_9622A_header table information --------")

columns = inspector_01.get_columns('Century_9622A_header')
for column in columns:
    print(column["name"], column["type"])
# Out:
# ---- Century_9622A table information --------
# Depth_M FLOAT
# GAM(NAT)_API-GR FLOAT
# SUSCEP_CGS E-5 FLOAT
# SANG_DEG FLOAT
# SANGB_DEG FLOAT
# MAG-VECT_AMPL FLOAT
# XINCL_MV FLOAT
# YINCL_MV FLOAT
# XFLUX_MV FLOAT
# YFLUX_MV FLOAT
# ZFLUX_MV FLOAT
# TEMP_DEG C FLOAT
# TEMP_CPS FLOAT
# SUSCEP_CPS FLOAT
# TENSION_CPS FLOAT
# TIME_MINUTES FLOAT
# well TEXT
# file TEXT
# TEMP_DEG REAL
# TIME_SECONDS FLOAT
# TENSION_POUNDS FLOAT
# ind INTEGER
# ---- Century_9622A_cals table information --------
# dateTime DATETIME
# sensor TEXT
# unitsStandard TEXT
# standard FLOAT
# response FLOAT
# file TEXT
# well TEXT
# toolSerial TEXT
# ind INTEGER
# ---- Century_9622A_header table information --------
# filetype NUMERIC
# filetypeID TEXT
# sysversion TEXT
# sysserial TEXT
# unit TEXT
# truckcal TEXT
# interval FLOAT
# start_depth TEXT
# end_depth TEXT
# dir TEXT
# engUnits TEXT
# toolSerial TEXT
# runDate DATETIME
# runTime TEXT
# Company TEXT
# Well TEXT
# Field TEXT
# County TEXT
# State TEXT
# Section TEXT
# Township TEXT
# Range TEXT
# Latitude TEXT
# Longitude TEXT
# LogMeasFrom TEXT
# DrillMeasFrom TEXT
# PermDatum TEXT
# ElevPermDatum TEXT
# ElevKellyBushing TEXT
# ElevDrillFloor TEXT
# ElevGndLevel TEXT
# DepthDriller TEXT
# CasingDiameter TEXT
# CasingBottom TEXT
# CasingType TEXT
# CasingThickness TEXT
# TimeCircStop TEXT
# LoggingUnit TEXT
# FieldOffice TEXT
# RecordedBy TEXT
# OtherServ_1 TEXT
# OtherServ_2 TEXT
# Remarks_1 TEXT
# Remarks_2 TEXT
# BitSize TEXT
# MeanSurfTemp TEXT
# TempGradient TEXT
# MagnDecl TEXT
# DensityMatrix TEXT
# NeutronMatrix TEXT
# MatrixDelta TEXT
# FluidDelta TEXT
# MudSampdrc TEXT
# MudResistivity TEXT
# MudTemp TEXT
# ResMudFiltrate TEXT
# TempMudFiltrate TEXT
# ResMudCake TEXT
# TempMudCake TEXT
# BoreholeFluid TEXT
# FluidDensity TEXT
# FluidVisc TEXT
# FluidpHy TEXT
# ElectricLogCut TEXT
# RigNum TEXT
# UWI TEXT
# License TEXT
# CasingOD TEXT
# Location TEXT
# RunNo TEXT
# ApiNo TEXT
# Witnessed TEXT
# ToolModuleVersion BIGINT
# Arrival TEXT
# Depart TEXT
# loggerTD TEXT
# Caliper TEXT
# runDateTime DATETIME
# file TEXT
# filepath TEXT
# ind INTEGER

# %%
# View all of the classes that automap found

# Using the inspector to print the column names within the 'measurement' table and its types

print ("---- Century_9622C table information --------")

columns = inspector_01.get_columns('Century_9622C')
for column in columns:
    print(column["name"], column["type"])

print ("---- Century_9622C_cals table information --------")

columns = inspector_01.get_columns('Century_9622C_cals')
for column in columns:
    print(column["name"], column["type"])


print ("---- Century_9622C_header table information --------")

columns = inspector_01.get_columns('Century_9622C_header')
for column in columns:
    print(column["name"], column["type"])
# Out:
# ---- Century_9622C table information --------
# Depth_M FLOAT
# GAM(NAT)_CPS FLOAT
# SUSCEP_CGS E-5 FLOAT
# SANG_DEG FLOAT
# SANGB_DEG FLOAT
# MAG-VECT_AMPL FLOAT
# XINCL_MV FLOAT
# YINCL_MV FLOAT
# XFLUX_MV FLOAT
# YFLUX_MV FLOAT
# ZFLUX_MV FLOAT
# TEMP_DEG C FLOAT
# TEMP_CPS FLOAT
# SUSCEP_CPS FLOAT
# TENSION_CPS FLOAT
# TIME_MINUTES FLOAT
# well TEXT
# file TEXT
# TEMP_DEG REAL
# ind INTEGER
# ---- Century_9622C_cals table information --------
# dateTime DATETIME
# sensor TEXT
# unitsStandard TEXT
# standard FLOAT
# response FLOAT
# file TEXT
# well TEXT
# toolSerial TEXT
# ind INTEGER
# ---- Century_9622C_header table information --------
# filetype TEXT
# filetypeID TEXT
# sysversion TEXT
# sysserial TEXT
# unit TEXT
# truckcal TEXT
# interval FLOAT
# start_depth TEXT
# end_depth TEXT
# dir TEXT
# engUnits TEXT
# toolSerial TEXT
# runDate DATETIME
# runTime TEXT
# Company TEXT
# Well TEXT
# Field TEXT
# County TEXT
# State TEXT
# Section TEXT
# Township TEXT
# Range TEXT
# Latitude TEXT
# Longitude TEXT
# LogMeasFrom TEXT
# DrillMeasFrom TEXT
# PermDatum TEXT
# ElevPermDatum TEXT
# ElevKellyBushing TEXT
# ElevDrillFloor TEXT
# ElevGndLevel TEXT
# DepthDriller TEXT
# CasingDiameter TEXT
# CasingBottom TEXT
# CasingType TEXT
# CasingThickness TEXT
# TimeCircStop TEXT
# LoggingUnit TEXT
# FieldOffice TEXT
# RecordedBy TEXT
# OtherServ_1 TEXT
# OtherServ_2 TEXT
# Remarks_1 TEXT
# Remarks_2 TEXT
# BitSize TEXT
# MeanSurfTemp TEXT
# TempGradient TEXT
# MagnDecl TEXT
# DensityMatrix TEXT
# NeutronMatrix TEXT
# MatrixDelta TEXT
# FluidDelta TEXT
# MudSampdrc TEXT
# MudResistivity TEXT
# MudTemp TEXT
# ResMudFiltrate TEXT
# TempMudFiltrate TEXT
# ResMudCake TEXT
# TempMudCake TEXT
# BoreholeFluid TEXT
# FluidDensity TEXT
# FluidVisc TEXT
# FluidpHy TEXT
# ElectricLogCut TEXT
# RigNum TEXT
# UWI TEXT
# License TEXT
# CasingOD TEXT
# Location TEXT
# RunNo TEXT
# ApiNo TEXT
# Witnessed TEXT
# ToolModuleVersion BIGINT
# Arrival TEXT
# Depart TEXT
# loggerTD TEXT
# Caliper TEXT
# runDateTime DATETIME
# file TEXT
# filepath TEXT
# ind INTEGER

# %%
inspector_01.get_table_names()
# Out:
# ['Century_0028AA',
#  'Century_0028AA_cals',
#  'Century_0028AA_header',
#  'Century_9013A',
#  'Century_9013A_cals',
#  'Century_9013A_header',
#  'Century_9238AA',
#  'Century_9238AA_cals',
#  'Century_9238AA_header',
#  'Century_9238CA',
#  'Century_9238CA_cals',
#  'Century_9238CA_header',
#  'Century_9622A',
#  'Century_9622A_cals',
#  'Century_9622A_header',
#  'Century_9622C',
#  'Century_9622C_cals',
#  'Century_9622C_header',
#  'sqlite_sequence']

# %% [markdown]
# ['Century_0028AA',
#  'Century_0028AA_cals',
#  'Century_0028AA_header',
#  'Century_9013A',
#  'Century_9013A_cals',
#  'Century_9013A_header',
#  'Century_9238AA',
#  'Century_9238AA_cals',
#  'Century_9238AA_header',
#  'Century_9238CA',
#  'Century_9238CA_cals',
#  'Century_9238CA_header',
#  'Century_9622A',
#  'Century_9622A_cals',
#  'Century_9622A_header',
#  'Century_9622C',
#  'Century_9622C_cals',
#  'Century_9622C_header',
#  'sqlite_sequence']

# %%
# reflect an existing database into a new model

Base_01 = automap_base()
Base_01.prepare(autoload_with=engine_01, reflect=True)


# reflect the tables
Base_01.classes.keys()
# Out:
# ['Century_0028AA',
#  'Century_0028AA_cals',
#  'Century_0028AA_header',
#  'Century_9013A',
#  'Century_9013A_cals',
#  'Century_9013A_header',
#  'Century_9238AA',
#  'Century_9238AA_cals',
#  'Century_9238AA_header',
#  'Century_9238CA',
#  'Century_9238CA_cals',
#  'Century_9238CA_header',
#  'Century_9622A',
#  'Century_9622A_cals',
#  'Century_9622A_header',
#  'Century_9622C',
#  'Century_9622C_cals',
#  'Century_9622C_header']

# %%
# Save references to each table (For use for SQL Queries if required)

# Map 0028AA class
db_0028AA = Base_01.classes.Century_0028AA
db_0028AA_cals = Base_01.classes.Century_0028AA_cals
db_0028AA_header = Base_01.classes.Century_0028AA_header

# Map 9013A class
db_9013A = Base_01.classes.Century_9013A
db_9013A_cals = Base_01.classes.Century_9013A_cals
db_9013A_header = Base_01.classes.Century_9013A_header

# Map 9238AA class
db_9238AA = Base_01.classes.Century_9238AA
db_9238AA_cals = Base_01.classes.Century_9238AA_cals
db_9238AA_header = Base_01.classes.Century_9238AA_header

# Map 9238CA class
db_9238CA = Base_01.classes.Century_9238CA
db_9238CA_cals = Base_01.classes.Century_9238CA_cals
db_9238CA_header = Base_01.classes.Century_9238CA_header

# Map 9622A class
db_9622A = Base_01.classes.Century_9622A
db_9622A_cals = Base_01.classes.Century_9622A_cals
db_9622A_header = Base_01.classes.Century_9622A_header

# Map 9622C class
db_9622C = Base_01.classes.Century_9622C
db_9622C_cals = Base_01.classes.Century_9622C_cals
db_9622C_header = Base_01.classes.Century_9622C_header

# %%
# Create our session (link) from Python to the DB
session = Session(engine_01)

# %%
# DB Load from SQL Database

# Century_0028AA
tool_0028AA_df_01 = pd.read_sql_table('Century_0028AA', engine_01)
tool_0028AA_cals_df_01 = pd.read_sql_table('Century_0028AA_cals', engine_01)
tool_0028AA_header_df_01 = pd.read_sql_table('Century_0028AA_header', engine_01)

# Century_9013A
tool_9013A_df_01 = pd.read_sql_table('Century_9013A', engine_01)
tool_9013A_cals_df_01 = pd.read_sql_table('Century_9013A_cals', engine_01)
tool_9013A_header_df_01 = pd.read_sql_table('Century_9013A_header', engine_01)

# Century_9238AA
tool_9238AA_df_01 = pd.read_sql_table('Century_9238AA', engine_01)
tool_9238AA_cals_df_01 = pd.read_sql_table('Century_9238AA_cals', engine_01)
tool_9238AA_header_df_01 = pd.read_sql_table('Century_9238AA_header', engine_01)

# Century_9238CA
tool_9238CA_df_01 = pd.read_sql_table('Century_9238CA', engine_01)
tool_9238CA_cals_df_01 = pd.read_sql_table('Century_9238CA_cals', engine_01)
tool_9238CA_header_df_01 = pd.read_sql_table('Century_9238CA_header', engine_01)

# Century_9622A
tool_9622A_df_01 = pd.read_sql_table('Century_9622A', engine_01)
tool_9622A_cals_df_01 = pd.read_sql_table('Century_9622A_cals', engine_01)
tool_9622A_header_df_01 = pd.read_sql_table('Century_9622A_header', engine_01)

# Century_9622C
tool_9622C_df_01 = pd.read_sql_table('Century_9622C', engine_01)
tool_9622C_cals_df_01 = pd.read_sql_table('Century_9622C_cals', engine_01)
tool_9622C_header_df_01 = pd.read_sql_table('Century_9622C_header', engine_01)

# %%
# create engine to Dataset 1 .sqlite
engine_02 = create_engine("sqlite:///Resources/RH_2021_Field.db")

# %%
# Create the inspector and connect it to the engine
inspector_02= inspect(engine_02)
# Collect the names of tables within the database
inspector_02.get_table_names()
# Out:
# ['Century_0028AA',
#  'Century_0028AA_cals',
#  'Century_0028AA_header',
#  'Century_0037A',
#  'Century_0037A_cals',
#  'Century_0037A_header',
#  'Century_0037C',
#  'Century_0037C_cals',
#  'Century_0037C_header',
#  'Century_9622A',
#  'Century_9622A_cals',
#  'Century_9622A_header',
#  'Century_9622C',
#  'Century_9622C_cals',
#  'Century_9622C_header',
#  'sqlite_sequence']

# %%
# reflect an existing database into a new model

Base_02 = automap_base()
Base_02.prepare(autoload_with=engine_02, reflect=True)


# reflect the tables
Base_02.classes.keys()
# Out:
# ['Century_0028AA',
#  'Century_0028AA_cals',
#  'Century_0028AA_header',
#  'Century_0037A',
#  'Century_0037A_cals',
#  'Century_0037A_header',
#  'Century_0037C',
#  'Century_0037C_cals',
#  'Century_0037C_header',
#  'Century_9622A',
#  'Century_9622A_cals',
#  'Century_9622A_header',
#  'Century_9622C',
#  'Century_9622C_cals',
#  'Century_9622C_header']

# %%
# Save references to each table (For use for SQL Queries if required)

# Map 0028AA class
db_02_0028AA = Base_02.classes.Century_0028AA
db_02_0028AA_cals = Base_02.classes.Century_0028AA_cals
db_02_0028AA_header = Base_02.classes.Century_0028AA_header


# Map 9622A class
db_02_9622A = Base_02.classes.Century_9622A
db_02_9622A_cals = Base_02.classes.Century_9622A_cals
db_02_9622A_header = Base_02.classes.Century_9622A_header

# Map 9622C class
db_02_9622C = Base_02.classes.Century_9622C
db_02_9622C_cals = Base_02.classes.Century_9622C_cals
db_02_9622C_header = Base_02.classes.Century_9622C_header

# %%
# Century_0028AA
tool_0028AA_df_02 = pd.read_sql_table('Century_0028AA', engine_02)
tool_0028AA_cals_df_02 = pd.read_sql_table('Century_0028AA_cals', engine_02)
tool_0028AA_header_df_02 = pd.read_sql_table('Century_0028AA_header', engine_02)

# %%
# Century_9622A
tool_9622A_df_02 = pd.read_sql_table('Century_9622A', engine_02)
tool_9622A_cals_df_02 = pd.read_sql_table('Century_9622A_cals', engine_02)
tool_9622A_header_df_02 = pd.read_sql_table('Century_9622A_header', engine_02)

# %%
# Century_9622C
tool_9622C_df_02 = pd.read_sql_table('Century_9622C', engine_02)
tool_9622C_cals_df_02 = pd.read_sql_table('Century_9622C_cals', engine_02)
tool_9622C_header_df_02 = pd.read_sql_table('Century_9622C_header', engine_02)

# %%
# create engine to Dataset .sqlite
engine_03 = create_engine("sqlite:///Resources/RH_2022_Field.db")

# %%
# Create the inspector and connect it to the engine
inspector_03= inspect(engine_03)
# Collect the names of tables within the database
inspector_03.get_table_names()
# Out:
# ['Century_0028AA',
#  'Century_0028AA_cals',
#  'Century_0028AA_header',
#  'Century_9622A',
#  'Century_9622A_cals',
#  'Century_9622A_header',
#  'Century_9622C',
#  'Century_9622C_cals',
#  'Century_9622C_header',
#  'sqlite_sequence']

# %%
# reflect an existing database into a new model

Base_03 = automap_base()
Base_03.prepare(autoload_with=engine_03, reflect=True)


# reflect the tables
Base_03.classes.keys()
# Out:
# ['Century_0028AA',
#  'Century_0028AA_cals',
#  'Century_0028AA_header',
#  'Century_9622A',
#  'Century_9622A_cals',
#  'Century_9622A_header',
#  'Century_9622C',
#  'Century_9622C_cals',
#  'Century_9622C_header']

# %%
# Save references to each table (For use for SQL Queries if required)

# Map 0028AA class
db_03_0028AA = Base_03.classes.Century_0028AA
db_03_0028AA_cals = Base_03.classes.Century_0028AA_cals
db_03_0028AA_header = Base_03.classes.Century_0028AA_header

# Map 9622A class
db_03_9622A = Base_03.classes.Century_9622A
db_03_9622A_cals = Base_03.classes.Century_9622A_cals
db_03_9622A_header = Base_03.classes.Century_9622A_header

# Map 9622C class
db_03_9622C = Base_03.classes.Century_9622C
db_03_9622C_cals = Base_03.classes.Century_9622C_cals
db_03_9622C_header = Base_03.classes.Century_9622C_header

# %%
# Century_0028AA
tool_0028AA_df_03 = pd.read_sql_table('Century_0028AA', engine_03)
tool_0028AA_cals_df_03 = pd.read_sql_table('Century_0028AA_cals', engine_03)
tool_0028AA_header_df_03 = pd.read_sql_table('Century_0028AA_header', engine_03)

# %%
# Century_9622A
tool_9622A_df_03 = pd.read_sql_table('Century_9622A', engine_03)
tool_9622A_cals_df_03 = pd.read_sql_table('Century_9622A_cals', engine_03)
tool_9622A_header_df_03 = pd.read_sql_table('Century_9622A_header', engine_03)

# %%
# Century_9622C
tool_9622C_df_03 = pd.read_sql_table('Century_9622C', engine_03)
tool_9622C_cals_df_03 = pd.read_sql_table('Century_9622C_cals', engine_03)
tool_9622C_header_df_03 = pd.read_sql_table('Century_9622C_header', engine_03)

# %%
tool_0028AA_df_01["Dataset"]="Cust_01"
tool_0028AA_cals_df_01["Dataset"]="Cust_01"
tool_0028AA_header_df_01["Dataset"]="Cust_01"

tool_0028AA_df_02["Dataset"]="Cust_02"
tool_0028AA_cals_df_02["Dataset"]="Cust_02"
tool_0028AA_header_df_02["Dataset"]="Cust_02"

tool_0028AA_df_03["Dataset"]="Cust_03"
tool_0028AA_cals_df_03["Dataset"]="Cust_03"
tool_0028AA_header_df_03["Dataset"]="Cust_03"

# %%
tool_9622A_df_01["Dataset"]="Cust_01"
tool_9622A_cals_df_01["Dataset"]="Cust_01"
tool_9622A_header_df_01["Dataset"]="Cust_01"

tool_9622A_df_02["Dataset"]="Cust_02"
tool_9622A_cals_df_02["Dataset"]="Cust_02"
tool_9622A_header_df_02["Dataset"]="Cust_02"

tool_9622A_df_03["Dataset"]="Cust_03"
tool_9622A_cals_df_03["Dataset"]="Cust_03"
tool_9622A_header_df_03["Dataset"]="Cust_03"

# %%
tool_9622C_df_01["Dataset"]="Cust_01"
tool_9622C_cals_df_01["Dataset"]="Cust_01"
tool_9622C_header_df_01["Dataset"]="Cust_01"

tool_9622C_df_02["Dataset"]="Cust_02"
tool_9622C_cals_df_02["Dataset"]="Cust_02"
tool_9622C_header_df_02["Dataset"]="Cust_02"

tool_9622C_df_03["Dataset"]="Cust_03"
tool_9622C_cals_df_03["Dataset"]="Cust_03"
tool_9622C_header_df_03["Dataset"]="Cust_03"

# %%
tool_0028AA_frames = [tool_0028AA_df_01,tool_0028AA_df_02,tool_0028AA_df_03]

tool_0028AA_df = pd.concat(tool_0028AA_frames)
tool_0028AA_df.to_csv("Output_data/tool_0028AA_df.csv")

# %%
tool_0028AA_cals_frames = [tool_0028AA_cals_df_01,tool_0028AA_cals_df_02,tool_0028AA_cals_df_03]

tool_0028AA_cals_df = pd.concat(tool_0028AA_cals_frames)
tool_0028AA_cals_df.to_csv("Output_data/tool_0028AA_cals_df.csv")

# %%
tool_0028AA_header_df_frames = [tool_0028AA_header_df_01,tool_0028AA_header_df_02,tool_0028AA_header_df_03]

tool_0028AA_header_df = pd.concat(tool_0028AA_header_df_frames)
tool_0028AA_header_df.to_csv("Output_data/tool_0028AA_header_df.csv")

# %%
tool_9622A_frames = [tool_9622A_df_01,tool_9622A_df_02,tool_9622A_df_03]
tool_9622A_df = pd.concat(tool_9622A_frames)
tool_9622A_df.to_csv("Output_data/tool_9622A_df.csv")

tool_9622A_cals_frames = [tool_9622A_cals_df_01,tool_9622A_cals_df_02,tool_9622A_cals_df_03]
tool_9622A_cals_df = pd.concat(tool_9622A_cals_frames)
tool_9622A_cals_df.to_csv("Output_data/tool_9622A_cals_df.csv")

tool_9622A_header_df_frames = [tool_9622A_header_df_01,tool_9622A_header_df_02,tool_9622A_header_df_03]
tool_9622A_header_df = pd.concat(tool_9622A_header_df_frames)
tool_9622A_header_df.to_csv("Output_data/tool_9622A_header_df.csv")

# %%
tool_9622C_frames = [tool_9622C_df_01,tool_9622C_df_02,tool_9622C_df_03]
tool_9622C_df = pd.concat(tool_9622C_frames)
tool_9622C_df.to_csv("Output_data/tool_9622C_df.csv")

tool_9622C_cals_frames = [tool_9622C_cals_df_01,tool_9622C_cals_df_02,tool_9622C_cals_df_03]
tool_9622C_cals_df = pd.concat(tool_9622C_cals_frames)
tool_9622C_cals_df.to_csv("Output_data/tool_9622C_cals_df.csv")

tool_9622C_header_df_frames = [tool_9622C_header_df_01,tool_9622C_header_df_02,tool_9622C_header_df_03]
tool_9622C_header_df = pd.concat(tool_9622C_header_df_frames)
tool_9622C_header_df.to_csv("Output_data/tool_9622C_header_df.csv")

# %%
# Close Session
session.close()
